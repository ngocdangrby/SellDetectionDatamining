# %% [markdown]
# # Bài toán xác định bài viết bán hàng
#
# ### Tóm tắt yêu cầu:
# Xác định một bài viết trên mạng xã hội có phải là bán hàng hay không?
# ### Bộ dữ liệu:
# 60.000 dòng trạng thái trên mạng xã hội đã được gẵn nhãn bán hàng hay không.
#
# ## Thực hiện
#
# ### Tiền xử lí dữ liệu
#
# Thêm các thư viện cần sử dụng:

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Đọc dữ liệu đầu vào và tách ra những data bán hàng và không bán hàng
#
# Nhìn qua bộ dữ liệu, chuyển các nhãn thành số:
# * 1 = không bán hàng
# * 0 = bán hàng

# %%
SELL = '__label__post_ban_hang'
NON_SELL = '__label__post_khong_ban'
data  = pd.read_csv('./data/input.txt', header = None, sep="\n")
tmp = data[0].str.split(" ", 1, expand = True)
df = pd.DataFrame(columns=['label', 'content'])
data['label'] = tmp[0]
data['content'] = tmp[1]
data.drop([data.columns[0]], axis='columns', inplace=True)
Encoder = LabelEncoder()
data['label'] = Encoder.fit_transform(data['label'])
data.head(5)
# Out:
#    label                                            content
# 0      1  Gsu khsi nek dep gai hk cho y kirn yk nhoaz kh...
# 1      1              Haiz ... chan wa. hoc-hoc-nua-hoc mau
# 2      1                                 Găng tay ngập shop
# 3      0  🌺 2 siểu phẩm XÔNG BẮC THẢO DƯỢC 🌺 ( Công dụng...
# 4      1                               Nổi nhớ dân trào 😂😂😂

# %% [markdown]
# Số lượng dữ liệu và từng loại label:
# * Bán hàng: 7935 (chiếm 13.2%)
# * Không bán hàng: 52065 (chiếm 86.8%)

# %%
data.groupby('label').count()
# Out:
#        content
# label
# 0         7935
# 1        51934

# %% [markdown]
# Xem những từ xuất hiện nhiều trên bộ dữ liệu:

# %%
# %run ./pre-process/top_words
top_words(data['content'].tolist(), file_name = 'top_before_pre')

# %% [markdown]
# Làm đẹp dữ liệu text qua các bước:
# * Chuyển thành kí tự viết thường
# * Loại bỏ các emoji
# * Chuyển đổi các định dạng giá cả $\Rightarrow$ __giá_sản_phẩm__
#    * Ví dụ: 500k, 500.000đ, 500.000vnđ, 5m, 5tr6, ...
# * Chuyển đổi link website 	$\Rightarrow$ __link_website__
#    * Toàn bộ link bắt đầu từ http, https, bit.ly, goo.gl
# * Chuyển đổi các dạng số điện thoại 	$\Rightarrow$ __số_điện_thoại__
#    * Ví dụ: +84946.123.45, 096-265-222, 096.265.222, ...
# * Xóa các dấu câu, kí tự lạ.
# * Xoá kí tự số
# * Tokenizer
#    * Chuyển các từ ghép có nghĩa thành một từ: xin chào $\rightarrow$ __xin_chào__, tóm tắt $\rightarrow$ __tóm_tắt__, kính đổi màu $\rightarrow$ __kính_đổi_màu__ ...
# * Xóa các data NaN

# %%
# %run ./pre-process/pre_process
data['content'] = data['content'].map(lambda s : pre_process(s))
data.dropna()
# Out:
# Loading model from file pre-process/vi-segmentation.crfsuite
#        label                                            content
# 0          1  gsu khsi nek dep gai hk cho y kirn yk nhoaz kh...
# 1          1                   haiz chan wa hoc hoc nua hoc mau
# 2          1                                 găng_tay ngập shop
# 3          0  siểu phẩm xông bắc thảo_dược công_dụng từng lo...
# 4          1                                   nổi nhớ dân trào
# ...      ...                                                ...
# 59864      1                                     còn ít mầu nữa
# 59865      0  đầm xòe cổ sen sát_nách chất da cá sỉ giá_sản_...
# 59866      1           người đẹp chuyển giới thái lan biểu_diễn
# 59867      1  do not understand why this walking throughout ...
# 59868      1  hòa chung không_khí rộn_ràng của cả nước u23 v...
#
# [59869 rows x 2 columns]

# %%
data['content'][10:30]
# Out:
# 10    sữa rửa mặt ohui miracle moisture sữa rửa mặt ...
# 11    chuc mừng sinh_nhật chj le nguyen em tuong vy ...
# 12    clutch đà_điểu sang_trọng cho nam call số_điện...
# 13    quần_jean chân viền ren hoa giá_sản_phẩm chất ...
# 14               mới_đó mà đã chủ_nhật cuối tuần vui_vẻ
# 15                                    nkìn a từ fía sau
# 16                                       chuc thu sn vv
# 17                         quả set up xấu thê_thảm nhất
# 18                         vẫn người chụp ảnh có tâm ấy
# 19    đầm ren hoa sang_trọng và tinh_tế và thanh_lịc...
# 20    kam on may pn to chuc sn mk tuy muon nhưng mk ...
# 21    một ngày lễ thật vui và ý_nghĩa chúc tất_cả th...
# 22    hom nay la ngay vui ve nhat cua gia dinh da co...
# 23                 hay tu nhien va vo tu nhu vay tot ko
# 24    tàn_nhang bẩm_sinh đã hết nhờ thảo_dược hồng h...
# 25    bộ đồ_chơi xúc xắc giá giá_sản_phẩm có số_lượn...
# 26
# 27    code ngày mã code2103 lông_vũ locke thần vũ lo...
# 28    e lam co vui ko o no do co nguoi van mong cho ...
# 29                                       ghi gì thì ghi
# Name: content, dtype: object

# %% [markdown]
# Sau khi đã xử lí dữ liệu text, xem những từ xuất hiện nhiều nhất trong bộ dữ liệu:

# %%
# %run ./pre-process/top_words
two_top_words(data, file_name = 'top_after_pre')

# %% [markdown]
# Khi nhìn vào biểu đồ những từ xuất hiện nhiều trong dữ liệu, ta dễ dàng thấy một số từ không mang tính phân loại hoặc từ không mang nhiều ý nghĩa, ví dụ: *và*, *là*, *có*, *cho*, ...
#
# Tiến hành loại bỏ những từ này bằng cách sử dụng bộ từ điển *stopwords*

# %%
# %run ./pre-process/top_words

stopwords = set(line.strip() for line in open('pre-process/stopwords.txt'))
data['content'] = data['content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
two_top_words(data, file_name = 'top_after_pre')

# %% [markdown]
# ### Vector hóa, training và đánh giá phương pháp:

# %% [markdown]
# Vector hóa dữ liệu sử dụng TF-IDF Vectorizer

# %%
# Tách dữ liệu thành tập train và test
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(data['content'], data['label'],test_size=0.3, random_state=42)

# Vecto hóa dùng TF-IDF Vectorizer
Tfidf_vect = TfidfVectorizer(max_features=5000, lowercase=False)
Tfidf_vect.fit(data['content'])

Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

# %%
# Phân loại dùng Naive Bayes và SVM để so sánh

# Naive Bayes
# fit tập train 
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)

# dự đoán
predictions_NB = Naive.predict(Test_X_Tfidf)

#  Tính Accuracy
print("Naive Bayes Accuracy -> ",accuracy_score(predictions_NB, Test_Y)*100)


# SVM
# fit tập train 
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)

# dự đoán
predictions_SVM = SVM.predict(Test_X_Tfidf)

# Tính Accuracy
print("SVM Accuracy -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# Naive Bayes Accuracy ->  96.69283447469518
# SVM Accuracy ->  97.73954679583542

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(Test_Y, predictions_SVM)
print('Confusion matrix:')
print(cnf_matrix)
# Out:
# Confusion matrix:
# [[ 2116   265]
#  [  141 15439]]

# %%
Test_Y.tolist()[100] != predictions_SVM[100]
# Out:
# False

# %%
cnf_matrix_Naive = confusion_matrix(Test_Y, predictions_NB)
print('Confusion matrix:')
print(cnf_matrix_Naive)
# Out:
# Confusion matrix:
# [[ 2086   295]
#  [  299 15281]]

# %%
Test_X_list = Test_X.tolist()
Test_Y_list = Test_Y.tolist()
FN = [Test_X_list[index] 
      for index in range(len(Test_Y_list)) 
      if Test_Y_list[index] == 1 and predictions_SVM[index] == 0]
FP = [Test_X_list[index] 
      for index in range(len(Test_Y_list)) 
      if Test_Y_list[index] == 0 and predictions_SVM[index] == 1]
FN
# Out:
# ['hóa da mặt căng bóng mịn quý xứ hàn phấn phấn tuyệt_kỹ giúp quý xứ hàn làn da căng bóng mịn kiềm dầu tuyệt_đối',
#  'g9 dòng son bình_dân giá sinh_viên chất son màu son tuyệt_vời giá_sản_phẩm nàng',
#  'leather crossbodybag is back nguyễn văn giai p đa kao q inbox imess zalo số_điện_thoại số_điện_thoại',
#  'giá ibox sms số_điện_thoại yahoo vanphongmobile81 số_lượng',
#  'trời mưa_gió bánh mỳ que ship đơn hàng c',
#  'nâng mi giá_sản_phẩm',
#  'đầu mùa du_lịch vé rẻ hn dan hn ps giá thuế phí',
#  'đặt_hàng e lo',
#  'ihi crane for slaes machine ihi crawler crane model cch2000 year boom crane giá_sản_phẩm 31m1m tower giá_sản_phẩm hook 200t 100t 50t 30t 5t hour meter 9500hrs location japan',
#  'sản_xuất máy uốn ống gia_công sản_phẩm www cksg vn',
#  'tứ_quý cẩm tập bán_lẻ tập giá_bìa giá_sản_phẩm q giá giá_sản_phẩm c link link_website giới_thiệu tác_phẩm đồ_sộ bậc minh nguyệt tác_giả văn_học mạng hàng_đầu văn đàn trung quốc chúa xinh_đẹp ước_mơ hoài_bão lớn_lao may yểu mệnh qua_đời nàng thác sinh con_gái sáu tiền_đồ gia_thế gái tưởng_chừng nhỏ_bé yếu_ớt ý_chí quyết_tâm tài_trí dựa nàng vực dậy gia_đình cục_diện triều số_phận mỉm cười hạnh_phúc nàng nàng bình_yên gia_đình nàng khuynh_đảo triều đình cuộc_đời nàng dần câu_chuyện cuộc_đời nàng dần hé lộ bốn tập truyện tứ_quý cẩm mong_đợi',
n thực_khách trở_lại café take away phát_triển rầm_rộ thu_hút giới trẻ hà nội tp hồ chí minh đặc_điểm loại_hình café tiện bảng menu cửa_hàng thuận_tiện khách_hàng gọi đồ thay_vì chỗ chờ phục_vụ khách_hàng thanh_toán quầy tiếp_cận hòa nhập nhanh_chóng loại_hình đồ uống khách_hàng chủ_yếu quán café take away trẻ cặp đôi học_sinh sinh_viên trung sinh_viên trường đại_học góp_triệu đồng quán cà_phê take away đường nguyễn trãi tp hcm thỏa mãn đam_mê chủ trung quán cà_phê tử_tế chi_phí xu_hướng tận quán cà_phê kiểu cũ vietq vn',
#  'hàng chụy',
#  'hnay đầu tý live hàng giải đen giá sập sàn nhá lót lông',
#  'e iphone 5s gold giá 3xxx inbox',
#  'mẫu next sz giá_sản_phẩm 6y',
#  'don t miss today s hottest arrivals from lyn liên_hệ add 190a trần bình trọng p q add lê văn sỹ p q add 26a xô_viết nghệ tĩnh p q bình thạnh contact số_điện_thoại số_điện_thoại',
#  'phông bbr mẫu cập bến',
#  'hít vá giá_sản_phẩm',
#  'số_điện_thoại',
#  'số_điện_thoại',
#  'ib e 10kg vòng thảo_dược cân nấm tuyệt_đối an_toàn ko tác_dụng phụ',
#  'mẫu bàn gallery chủ_đề',
#  'chân shipper vip vợ nhu_cầu ship tận d',
#  'mn ủng_hộ nha hàng bao đẹp',
#  'mứt tết đặt_hàng đi ty dừa bánh_tẻ dừa nạo sợi sẵn',
#  'hoa loa_kèn nở hoa rời đất mẹ giá yêu gsduong bachlanglang maimailabaoxa',
#  'đôi môi son môi vật bất ly_thân chị_em tôn nét đẹp phụ_nữ nàng sẵn túi son môi diện màu son phụ_nữ theo_dõi viết thông_tin chi_tiết link_website',
#  'hôm bữa a e hàng inbox giùm e nha e trả_lời',
#  'số_điện_thoại',
#  'đinh_lăng đinh_lăng điêu_khắc lh số_điện_thoại',
#  'het hang s3 túi sợi tre màu đỏ thích_hợp móc vs đan váy_áo hè thu giá giá_sản_phẩm đăng_kí mẫu địa_chỉ sdt ck cod lưu_ý đặt_hàng vui_lòng ko huỷ',
#  'giá_sản_phẩm môi cong',
#  '9a14 trường thcs vinschool có_lẽ thanh_xuân ghi_nhớ lãng_quên đánh kia quý_giá nằm tâm_trí follow us on facebook link_website from namnguyenstudio with love chi_tiết liên_hệ link_website hotline số_điện_thoại số_điện_thoại wedsite link_website add ngõ thái thịnh hà nội',
#  'sẵn sẵn v',
#  'thông_báo khẩn siêu bão g3 vinhomes green bay căn_hộ đa_năng quần_thể vịnh xanh phố đắc_địa_chỉ bigc giá_sản_phẩm đối_diện trung_tâm hội_nghị quốc_gia tương_đương giá_sản_phẩm giá giá_sản_phẩm căn_hộ văn_phòng thuê ngân_hàng vay vốn ls diện_tích linh_hoạt 60m2 thông_tin giá test 1pn giá triệu tỷ 2pn giá tỷ tỷ góc 2pn tỷ tỷ thô giá_sản_phẩm m2 thông thuỷ tư_vấn lh số_điện_thoại',
#  'rạch giá biến',
#  'đầm chun macxxi rin mỏng mát lắm giá_sản_phẩm',
#  'số_điện_thoại',
#  'phụ_nữ đừng bận chăm_sóc làm_đẹp đẹp làm_đẹp quyền_lợi trách_nhiệm hãytrảinghiệmvàcảmnhậntừngngày niceday serum 3in1 đôi dưỡng da hoàn_hảo princesswhite giá_sản_phẩm',
#  'chất cotton']

# %%
Naive.predict(Tfidf_vect.transform([pre_process("""Hương chính: Gỗ tuyết tùng Virginia, Hương Va ni (Vanille), Trầm hương, Cây thuốc lá. Vừa ngọt ngào vừa mùi thuốc lá.
Phong cách: Trẻ trung , nam tính, quyến rũ, hơi ăn chơi bar sàn tí nếu xịt nhiều phát, thích hợp hẹn hò, văn phòng.
Cảm nhận của mình về loại nước hoa này là vậy ạ""")]))
# Out:
# array([0])

# %%
SVM.predict(Tfidf_vect.transform([pre_process("""Tôi đã mua chiếc áo này giá """)]))
# Out:
# array([0])

# %%
# input_data  = pd.read_csv('./data/sell_detection_test.v1.0.txt', header = None, sep="\n")
input_data = [line.rstrip('\n') for line in open('./data/sell_detection_test.v1.0.txt')]
# df = pd.DataFrame(columns=['label', 'content'])
# data['label'] = tmp[0]
# data['content'] = tmp[1]
# data.drop([data.columns[0]], axis='columns', inplace=True)
# Encoder = LabelEncoder()
# data['label'] = Encoder.fit_transform(data['label'])
# data.head(5)
len(input_data)
# Out:
# 98893

# %%
input_data_ = [pre_process(x) for x in input_data]

# %%
input_data_
# Out:
# ['béo mà',
#  'minh la tai nguyen',
#  'moi bat dc con nay nhau dc hok',
#  'bữa ăn sáng trên bầu_trời',
#  'gặp được nhau đã là cái duyên đến với nhau bên cạnh nhau quan_tâm nhau có_lẽ là do số_phận năm thanh_xuân có nhau lãi được cục p s mỗi năm lãi đều như vậy thì lời to rồi 5year_anniversary htlovemn kếhoạch5nămlần1',
#  'sơri võ',
#  'ngu thoj chuc ka nha ngu ngon',
#  'thực_hiện chính_sách đại_lý mới nhằm chống bán phá_giá để bảo_vệ thương_hiệu và các đại_lý của istitch kể từ nay istitch chỉ bán cho đại_lý ở mỗi tỉnh_thành các quý đại_lý có nhu_cầu_xin vui_lòng liên_hệ email thanhhongdo @ gmail com để lấy báo_giá riêng nhé xin cám_ơn',
#  'snowntown sài gòn',
#  'ດ ົ ນໆໄປເທ ື ່ ອ ມ ່ ວນຫ ຼ າຍມ ື ້ ນ ີ ້',
#  'tàu đã bắt_đầu rời bến cả đoàn đã sẵn_sàng đến với trường sa tạm_biệt phú thọ tạm_biệt tttt của tôi',
#  'gel phụ_khoa dung_dịch vệ_sinh phụ_nữ linh hương hàng chuẩn auth mọi kh đều rất hài_lòng về chất_lượng dung_tích lớngấp lần các sp trên thị_trường 250ml dùng được tháng có tác_dụng làm sạch khử mùi sát_trùng hỗ_trợ trị viêm nấm ngứa nhiễm_khuẩn cân_bằng độ ph ngăn_ngừa các bệnh phụ_khoa khử mùi hôi khó_chịu giây và quyết_định chất_lượng cuộc_sống là ở đây',
#  'xjn chao cac ty nho nem gach jt thoj nha mjh ko mun phaj nhap vjen dau kakakakaka',
#  'buon la day haha',
#  'đêm_hôm nọ mọ',
#  'con_trai yêu của mẹ con biết đấy thế_giới này thật lớn con ạ vì trái_đất của chúng_ta đang sống chỉ là hạt bụi trong vũ_trụ bao_la thôi thế_mà mẹ thật may_mắn vì dù thế_giới rộng_lớn đến như vậy mẹ không bao_giờ cảm thấy lạc_lõng con là niềm động_lực lớn_lao nhất của mẹ dù cả thế_giới có làm mẹ buồn thì cũng chẳng sao con ạ kệ đi giờ mẹ đã có soái ca của mẹ rồi mà con_trai của đại soái ca bố đôi lúc muốn con mãi bé_nhỏ trong vòng_tay mẹ thế_mà chàng trai của mẹ sắp có_tuổi rồi đấy',
#  'gà trống',
#  'yasu thứ giá_sản_phẩm đó còn hàng ko',
#  'mới yo có tháng mà đã có con rồi',
#  'ky niem mien bac',
#  'thế_giới ngoài kia ồn_ào quá giữa cuộc_đời đông_đúc đôi lúc vẫn thấy bơ_vơ',
#  '   ',
#  'hello december rạng_rỡ để chào tháng tháng này sẽ cố_gắng dành nhiều thời_gian hơn cho bạn ray ảnh chưa qua photoshop',
#  'giải bóng_đá cựu học_sinh tĩnh gia ii nơi những con_người tĩnh gia ii giao_lưu gặp_gỡ và là nơi khơi dậy đam_mê khẳng_định mình likeshare',
#  'cũng hội như mọi người_ta vê thôi',
#  'ai an po xit k',
#  'đầm ren ôm xanh bạc_hà tươi_mát liên_hệ hotline giá_sản_phẩmể mua hàng nhé các cô gái',
#  'happy new year một năm mới bình an ntnt_22',
#  'hic hic ngủ dậy soi gương mọc vài cái mụn chắc k hợp nơi đây',
#  'đứa ni đau đứa tê đau may_mà cả đứa điều lỳ như trâu công_nhận giống mẹ hăn quậy đêm nhưng ngày chơi như giặc cùng lắm đau ngày là khỏe',
#  'mồng đầu tháng với nho và bò sữa',
#  'gia_đình là tất_cả mãi vui_vẻ và hạnh_phúc d',
#  'mua sao bang ne uoc dj ae',
#  'có_lẽ em phải sống với nỗi đau và nước_mắt',
#  'thả hồn vào gió sầm sơn ngay nắng',
#  'k cần người phải quá sâu_sắc chỉ cần bờ vai người đủ rộng',
#  'thấy get chưa',
#  'rụng tim3',
#  'k bit từ những năm nào hnay tự_nhiên c lại tìm thấy hji',
#  'trận đấu siêu kinh_điển',
#  'nhờ như thế mới nhận ra dk chữ tình bn thoi cố gắg từ_bỏ vượt qua lưu à làm lại cuộc_đời cho ổn_định lại thôi',
#  'bên nhau năm qua bao sóng_gió đến ngày chung đôi xây_đắp ngôi nhà_riêng thì ko vượt qua được năm mọi lý_do đúng sai cũng chẳng để làm_gì khi một người đã hết tình_cảm_tình_yêu thật_sự càng lúc càng đắt_giá hay sao hãy cứ là tình_nhân đừng là vợ là chồng rồi nhìn nhau chán_ngán',
#  'hoành_tráng',
#  'dell inspiron với chip skylake mới nhất của intel vga amd radeon ™ r5 m335 4gb gddr3 mạnh_mẽ với màu silver và black cấu_hình core i5 cpu intel core ™ i5 6200u 3ghz 3mb cache l3 up max to 8ghz ram 4gb ddr3l 1600mhz hdd 1tb 5400rpm sata display ” hd x truelife led backlit display vga amd radeon ™ r5 m335 4gb gddr3 odd dvd rw super multi os ubuntu trọng_lượng 32kg cấu_hình core i7 cpu intel core ™ i7 6500u 5ghz 4mb cache l3 up max to 1ghz ram 8gb ddr3l 1600mhz hdd 1tb 5400rpm sata display ” hd x truelife led backlit display vga amd radeon ™ r5 m335 4gb gddr3 odd dvd rw super multi os ubuntu trọng_lượng 32kg bảo_hành tháng tại dell hỗ_trợ đổi trong ngày đầu nếu có lỗi do nhà sản_xuất vui_lòng liên_hệ số_điện_thoại viber zalo 0giá_sản_phẩmể có thông_tin chi_tiết',
#  'mẹ oi con sợ lắm',
#  'đai ca quậy quá',
#  'past việt nam cố lên',
#  'xoan uốn cụp cắt nhuộm các kiểu cho bác cô chị_gái xinh_đẹp',
#  'pui sag zz nka daj gd faecbook ng moi tot lah',
#  'huy pepsi',
#  'chuyển sim đang dùng thành sinh_viên viettel giá_sản_phẩm chuyển_khoản hoặc giá_sản_phẩm thẻ cào mobi giá_sản_phẩm chuyển_khoản hoặc giá_sản_phẩm thẻ cào vina giá_sản_phẩm chuyển_khoản hoặc giá_sản_phẩm thẻ cào ưu_tiên thanh_toán chuyển_khoản vietcombank hồ_sơ cần gửi để làm số cần làm và số thường_xuyên gọi đi ảnh chứng_minh thư hai mặt bạn lấy điện_thoại chụp rõ nét ngay_ngắn tắt flash hồ_sơ gửi qua facebook hay zalo số_điện_thoại số_điện_thoại chuyển ngay trên sim của bạn hoặc người_thân đang dùng',
#  'việt nam chiến thang nhat dinh pai say de chuc mừng',
#  'con nhà chế',
#  'qq gì vậy',
#  'nhậu',
#  'hj hj h ơj vao nhan hag nek',
#  'trả sau km siêu rẻ giá bằng cân thịt số_điện_thoại số_điện_thoại số_điện_thoại số_điện_thoại số_điện_thoại số_điện_thoại 7số_điện_thoại số_điện_thoại 9số_điện_thoại số_điện_thoại số_điện_thoại số_điện_thoại số_điện_thoại',
#  'túi đeo chéo giá giá_sản_phẩm liên_hệ hạnh nguyên số_điện_thoại',
#  'lên đi',
#  'i love myself very much',
#  'nếu set cái ảnh này làm ava thì chắc_chắn tao đang rất rất thèm khái cái gì đó hoặc đơn_giản là chán đời',
#  'đừng bao_giờ nói không_thể khi mình chưa thử',
#  'chiến thôi anh_em ơi',
#  '  nhạt    ',
#  'kobelco clawer crane for sales location korea model 2f year boom giá_sản_phẩm jib giá_sản_phẩm hook 150t ball',
#  'blazer xuất hàn kasper siêu độc vừa về màu như hình size s m tương_đương số_lượng ít giá giá_sản_phẩm hàng có sẵn tại đặng tiến đông hà nội số_điện_thoại đà nẵng hải phòng số_điện_thoại',
#  'ki niem',
#  'chán dạo này mất nqủ trầm trọq nqày thì nqủ dk từ tiếq p d còn tối thì kúq chỉ nqủ dk hơn cả chục tiếq d chắc chớt mất keke v',
#  'thành chu du miên',
#  '',
#  'mọi người nhấn vào ảnh like cho em_trai thuý nha cảm_ơn mọi người nhek',
#  'lan oi chj bbon day khoe k nho con lam ak',
#  'haza chan lam roj nguoj co vjc lam thj muon o m k co j lam thj laj muon dj lam',
#  'hjhj thay cho mới',
#  'con traiiiiii cua bo',
#  'đuỵt cày nát lâm đồng ko có bóng gái',
#  'cảm_giác bây_giờ vẫn còn đang phê lắm đâu ra chàng trai điển_trai lại hay ra_phết',
#  'gì dương chúc thảo ly sn vv va luon khoe manh_nha thu phi',
#  'khoác kaki lớp có_thể mặc cặp nha form y hình giá hạt_dẻ',
#  'hay cha ne',
#  'việt nam thắng rồi ai bia nào ai bia đê e mời ngay và luôn nhá càng đông càng vui đê',
#  'y sưu_tầm conbànbên conbanben pageconbànbên pageconbanben',
#  'hai da doi dc moi ban ma gio mua mam kg co co aj hung voi e kg',
#  'đường_phố muôn màu',
#  'kem nền mới nhất của ga với khả_năng kiềm dầu tốt tạo lớp nền mỏng_tang mà vẫn che_phủ sản_phẩm lí_tưởng cho mùa hè này',
#  'diễn sâu chị e tui có nhiu là giỏi hehe chào chiều mb fb',
#  'tối nay ai ra đường cùng anh hôg có thì',
#  'vk ăn chè thái đặc_biệt nè',
#  'ai có nhu_cầu đăt giò tết cứ liên_hệ vs e rất hân_hạnh dc phục_vụ quý_khách đảm_bảo giò ngon chất_lượng nhé mọi người',
#  'day la coc vau nha mai tay hien',
#  'now i have my own kobe',
#  'ko nhịn dc cuoi',
#  'tuy da anh den nhung ma long anh trang tai anh lo kiem tien nen anh giang nang anh moi den anh kn dep nhu em nghi mien la a chung thuy voi em thoi',
#  'xem co tuong co up on cho windows phone',
#  'sở_thích dị vc',
#  'áo sơ_mi nam giá giá_sản_phẩm có size s m l áo thun nam giá giá_sản_phẩm có size s m l xl',
#  'ui dễ thuog chu bo',
#  'hô hô trần kim lua lưu lại đến lúc đi đỡ phải nghĩ d',
#  'có sự_thật trên thế_giới bạn hk thể bỏ xà phòg vào mắt mk bạn hk thể điếm dc tóc mk bạn hk thể thở bằg lổ mũi khi thè lưởi ra bạn vừa ms lm điều số sau khi bạn lm xog điều số3 bạn nhận ra hoàn_toàn có_thể chỉ bạn giốg con bạn đag cừơi vì bạn biết bạn ms bị lừa',
#  'hai tình_yêu của e ợ',
#  'em da cap ben an toan cam oanh truong da nhan em vao doi',
#  'tối hôm ấy nhà_nghỉ bình_dân giá_sản_phẩm đêm',
#  'áo_khoác lime còn màu ngọt_ngào nha khách sỉ giá_sản_phẩm lẻ giá_sản_phẩm',
#  'cô trao cho em thêm động_lực tự_tin trước lúc biểu_diễn',
#  'đặt mua dw chính hãng tại việt nam link_website đồng_hồ dw tại pradivywatch giá chỉ từ 2tr5 cho hàng order giá_sản_phẩm cho hàng có sẵn đảm_bảo chính hãng full box kèm thẻ bảo_hành giá luôn rẻ hơn giá niêm_yết hàng order hoặc có sẵn dw dwwatch danielwellingtonwatch danielwellington hnbdg daniel wellington là thương_hiệu đồng_hồ đến từ thụy điển với các
#  'intergrity',
#  'hello sunday',
#  'điêu mua do cac ba nuga best chieng lê_thê hiên',
#  'chủ_nhật em',
#  'siblings day',
#  'gala dinner cuối năm tại tổng công_ty ico group',
#  'đau răng k thể tưởng',
#  'cam on het tat cac chi em cac ban va cac chau da chuc mung sinh nhat cua nguyet nhe',
#  'moi nguoi cho nhan xet ve nhung dieu cuoi nay cai hjhj beo tuan trân lỳ',
#  'mong nhận được sự giúp_đỡ của tất_cả mọi người',
#  'mong là ngày_mai sẽ tốt hơn',
#  'nóng',
#  'ba co do co ban nao ket mot trong ba co k hjhjhj',
#  'dcme',
#  'u23 tuy ko vô_địch nhưng rất hãnh_diện vì các em giờ nạp năng_lượng thôi tự thưởng bản_thân',
#  'đang cam thay buon nhung ko sao vì',
#  'lac trôi nào',
#  'làm này ăn rùa nguyễn',
#  'thiếu tí may_mắn nữa',
#  'tranh_thủ làm mứt tết làm loại thất_bại do thiếu kinh_nghiệm',
#  'để tiết_kiệm tiền_bạc và thời_gian chúng_ta hãy yêu nhau từ cái nhìn đầu_tiên hùng yuuki ysố_điện_thoại 4t',
#  'link_website',
#  'sống độc_thân không có nghĩa_là bạn yếu_kém đến mức không có ai yêu mà nó có nghĩa_là bạn đang đủ mạnh_mẽ để chờ_đợi những gì thật xứng_đáng ảnh cũ',
#  'sợ vk cho nó lành k rồi đi tìm từng mảnh mệt lắm',
#  'chuc ngu ngọn',
#  'mệt moi dau dớn vô_cùng tai xao moi thứ k tốt_đẹp khíến cho ngta pai bùn lo_lắng lai kứ di theo tôi vậy tôi dã wá mệt và đau_đớn oy chán tất kả moi thứ hixhjx',
#  'haizzz có 1một thói quyen la sáng ngủ dậy trải tóc p s kắt tóc ngắn rùi kòn đâu nữa ở hb tóc ngắn và tkằg ngốc',
#  'bị chụp lén mà cũng dễ xương kkk p s thôi mà kệ post lên luôn kkk',
#  'không phải ai cũng biết những điều này đâu o xem thêm tại 9rac kho video vui vật_vã link_website',
#  'chang co le',
#  'ăn vô cho có sức để học con chử nửa xa_xôi thế đấy',
#  'vga union cup những hình_ảnh đầu_tiên về đội miền nam và miền bắc sân golf long thành chiều nay nhộn_nhịp hơn bao_giờ hết khi xuất_hiện những thành_viên của đội_tuyển miền bắc và miền nam đội miền bắc trong những bộ trang_phục vàng xanh được tài_trợ bởi ping le coq sportif còn đội miền nam là cam trắng của taylormade adidas hai đội đã có buổi ra_mắt truyền_thông rất ấn_tượng',
#  'muỗm đã nở mà em chưa sẵn_sàng',
#  'năm truoc minh ` ma biet co cai mv nay ` thi',
#  'noen   ',
#  ' năm  ',
#  'đêm là cái lúc màn đêm buông xuống và méo buồn_ngủ',
#  'day la ngay vui cua em gai',
#  'cả ngày_giờ đã đến_nơi',
#  'mot nam co ngay trung_thu troi lai mua buon thay cho cac chau thieu nhi',
#  'bạn_bè thì bẩn thôi nhìn e vui rồi ngủ cho qa ngày',
#  'tại_sao lại bị out fb nhỉ',
#  'aaa',
#  'isekai maou to shoukan shoujo no dorei majutsu',
#  'chuc a sn zz hp nhe',
#  'cảm_ơn tất_cả mọi người đã nhớ và gửi lời chúc tới sn của tôi xin chân_thành cảm_ơn',
#  'a nay vua an vua xui tu di day',
#  'đôi lúc đặt niem tin quá nhiều vào ng để r nhận lại đk gì ngoài chữ coi_thường',
#  'hôm_nay mẹ anh lại tông_đơ cho a đỡ già đấy quân nguyễn',
#  'góc chồ nhờ_vả free combini lawson ga bạn nào chưa có vc muốn làm bảo m nhá yêu_cầu làm đc ca tối đêm',
#  'bảng giá sản_phẩm bên mình nhé mua từ sp trở lên sẽ đc gia ưu_đãi vừa hiệu_quả cao vừa tiết_kiệm nhé face kem face frozen giá_sản_phẩm sữa rữa mặt beone giá_sản_phẩm giá_sản_phẩm giá_sản_phẩm kem face giá_sản_phẩm kem face giá_sản_phẩm giá_sản_phẩm giá_sản_phẩm kem face giá_sản_phẩm bùn ủ giá_sản_phẩm triệu giá_sản_phẩm kem trị nám giá_sản_phẩm kem trị mụn beone giá_sản_phẩm sữa rữa mặt beone giá_sản_phẩm giá_sản_phẩm giá_sản_phẩm body sữa tắm frozen giá_sản_phẩm kem body giá_sản_phẩm giá_sản_phẩm giá_sản_phẩm sữa tắm frozen giá_sản_phẩm kem body cốt lạnh giá_sản_phẩm set tắm trắng scandal giá_sản_phẩm giá_sản_phẩm giá_sản_phẩm sữa tắm frozen giá_sản_phẩm kem body giá_sản_phẩm nước thần olaf giá_sản_phẩm giá_sản_phẩm triệu thay da sinh_học nước thay da tay_chân giá_sản_phẩm nước thay da toàn_thân giá_sản_phẩm nước thay da toàn_thân giá_sản_phẩm tặng hộp kem 250g set tắm trắng nước thay da tay_chân giá_sản_phẩm tặng hộp kem 250g set tắm trắng _ kem dưỡng trắng cozy giá_sản_phẩm 250g _ set tắm trắng giá_sản_phẩm set',
#  'em tôi',
#  'đúng hay sai',
#  'my tank',
#  'đêm nay mát có_lẽ ngũ ngon hơn',
#  'quyết_tâm giảm béo',
#  'unisex public disney',
#  'u23 việt nam',
#  'nhân ngày nhà_giáo việt nam xin chúc các thầy cô_giáo những người lái_đò nhiều sức khỏe và thành_công trong sự_nghiệp trồng người',
#  'kem tri mun su dung trong 7ngay bao dam het mun lien he số_điện_thoại gap nhi giá_sản_phẩm',
#  'vui qua',
#  'nhận tài_liệu quỷ học',
#  'chuc ngủ ngon den aj do',
#  'mông e ý đẹp quá',
#  'cười',
#  'đầu năm làm cái pen chơi e lép đến mỏi cả tay',
#  'đầu xuân',
#  'troi mua roi ai thich an thjt cho cham man tom ko trinh trinh',
#  'dù đi bất_cứ nơi đâu hãy tự_hào nói tôi người hải phòng nhé',
#  'đâu phải cứ cười là vui cứ thích là đến cứ hờn là đi',
#  'những cái gì đau_khổ ai đúng ai sai nó đã qua rồi mập chúc người bạn năm đó luôn hạnh_phúc',
#  'cậu ghét tôi lắm hả',
#  'feedback serum_tế_bào_gốc_charme thích thế này bảo sao ai cũng ghiền',
#  'đơn giải thằng có ghẹ lạng',
#  'a nói e ko xjnh pởj vj e la nguoj dep nhât a noj a ko yeu pởj vj a đã wá yêu nguoj e pjt ko e ơj traj tjm a đã chêt theo e cuoc đơj dâu aj pjt chuơk aj khj yêu ko hề hôj tjêc',
#  'hạnh_phúc nha a',
#  'lòng đâu tình phai',
#  'tất_niên cùng ae',
#  'chúc_mừng e snvv nhé tùng nguyễn',
#  'chờ lời bình',
#  'thỏ con đc 9m14d',
#  'có_lẽ say sẽ tốt hơn',
#  'cần cái màn dầy bóc máy cụ nào có bán em với ạ',
#  'lên đi a ơi',
#  'thầy phán mà lị',
#  'mùa xuân nghe mấy bài này thì chỉ có chuẩn',
#  'bà_con ai có nhu_cầu bơi hết vào nèo',
#  'vgdhghgs',
#  'đáy biển tuy sâu nhung con ng do dc long ng tuy can mà ai đoán dc dau',
#  'thanh_niên cua gái',
#  'áo thun nam adidas trụ có màu size m l xl hàng có sẵn',
#  'nó ghi cái gì đọc ko ra lun ak',
#  'cúp siêu siêu kiện_tướng danh_thủ luan đồng vs cao_thủ quan nguyen phần_thưởng 1ly cf free',
#  'im ok',
#  'bao_nhiêu người ở bên cạnh bạn lúc vui cũng không bằng một người ở bên cạnh bạn lúc cần',
#  'anh có còn yêu',
#  'diêm vương chủ_nợ ông bán quan_tài',
#  'cuộc_sống thật đẹp khi có mọi người cảm_ơn đời đã đưa những thiên_thần ấy đến bên tôi yêu yêu và yêu tất_cả mọi người',
#  'hoa đẹp hoa tươi hoa vẫn tàn tình sâu tình nặng_tình vẫn tan rượu đắng rượu cay rượu vẫn hết người hứa người thề người vẫn quyên',
#  'riêng một góc trời',
#  'đau_đầu',
#  'loài hoa mới xuất_hiện_tại việt nam ah hoa đỗ_quyên ngủ_đông e bán mọi người ủng_hộ e với ah nhìn không khác_gì bó củi khô mà_lại tạo nên cơn_sốt mà chơi được khoảng tháng ah hàng tuần nữa mới về ah em giải_thích thế này ah nó là hoa đỗ_quyên ngủ_đông sẽ hồi_sinh sau khi cắm nước nở bung ra cực_kì đẹp ah quá_trình hồi_sinh sau khi bạn cắm nước những cành lá mà bạn nghĩ là héo khô sẽ bung ra sau đêm những ngày tiếp_theo búp sẽ thức dậy và xòe nở khoảng tuần hoa đã nở bung đầy cánh khi đó hoa vẫn còn màu hồng tím nhạt dần_dần theo thời_gian sẽ tím đậm_đà nếu bạn thay nước thường_xuyên nhiệt_độ phòng khoảng độ ngày tết nếu bạn trưng đỗ_quyên trong nhà có tác_dụng hóa giải luồng khí xấu xua_đuổi tà_ma đem đến hồng vận may_mắn tài_lộc cho gia chủ cành dài 60cm bó to khoảng cành nếu chưa cắm bạn cất_giữ nơi khô_ráo tránh ánh nắng trực_tiếp thì giữ được ngày nhé sau khi cắm sẽ chưng được tháng còn có_thể đâm chồi xanh mơn_mởn vì để được rất lâu nên các bạn nhanh tay đặt ngay từ bây_giờ để bán và chưng tết nhé',
#  'alone          ',
#  'ở một góc nào đó vẫn có người vô_tình bỏ mặc người mà chỉ chú_tâm vào công_việc p s',
#  'thah wa cua ca buoi chiu dc co 3c nhu z day',
#  'bon sieu co',
#  'nếu tôi trưởng_thành và pt suy_nghĩ hơn',
#  'cay nha la vuon se dua ba e nay vo noi len via thoi ca nha oi',
#  'vn vô_địch con',
#  'mương hôm_nay có tâm ghê chọn đúng ngày trọng_đại của chị_em cám_ơn nhiều nhé cứ thế phát_huy với ạ 305happyyoonaday',
#  'rượu càng uống nhưng chẳng say em nào có hay',
#  'chuc pn hp nhar hi',
#  'chiều hưởng_ứng đi xem bóng_đá thôi',
#  'dành cả tuổi thanh_xuân cho nhau muốn con_trai mẹ lớn lên trong vui_vẻ và hp nhất heart heart heart',
#  'a buon khj e lang wê a dj mat roj phaj hok e haj cho a bt mot su that la ngon ngao haj la dang cay ha l',
#  'theo phong chao anh dau nam',
#  'sao nay mjh cam tkay bu0n t0j ng pan tkan cua mjh ma ko hjeu dc mjh tky mjh pjt lam sao dau ko mu0n ngj ma tu nhjen kh0e mj r0j le cu0c d0j tkat lam bat c0ng',
#  'một ngày đầy ý_nghĩa tonhoasencùngemtớitrường',
#  'bao tran choj voj trong dem pun va kan mok nguoj hju dk nuj bun trog bao huhuu',
#  'người lạ ơi cho tôi mượn bờ vai đi',
#  'làm lễ đi bạn',
#  'xịt khử mùi hôi chân khử mùi trong 48h dùng buổi tối sau khi rửa sạch chân đều_đặn mỗi ngày ở tuần đầu tuần thứ dùng ngày tuần tuần thứ dùng lần tuần',
#  'ngheo nen nhju ng mat cam qua',
#  'nếu biết ngày_mai e lấy chồng chúc e hạnh_phúc có được không hiiiii',
#  'nụ cưới tỏa nắng',
#  'bjt khi nào moi đk jk chơi chug như v nua tar nhớ ngax đó qa',
#  'cam dong thu cua con_gái con_gái rui vào tui mẹ bảo con tang mẹ mẹ vui vi con da lon yêu con nhiều lam',
#  'hoan_hô hoàng hoa thám hốt hết giải lun các bạn giỏi lém _',
#  'nhận ra ai k ngọc hà',
#  'doi la vay',
#  'sog voi mot so thanh phan nhin thay da nong het ca mat',
#  'xóm tân hòa nè a dũng hoàngdũng ơi a bjt ai k',
#  'mẹ ơi con buồn quá khóc một_chút dược không con thấy mình lạc_lõng giữa triệu người mênh_mông đời cũng như dòng sông cạn hay sâu vẫn chảy con bấu đời mệt quá chai_sạn hằn đôi tay đi qua nhiều cay_đắng con muốn lòng dịu lại mà đời vốn khắc_nghiệt con lạc_lõng di sai đêm nay cơn mưa lớn như rút bão lên_đời một_mình con noi day thèm về nương vai mẹ ngủ một giấc ngon_lành kệ lòng người bội_bạc kệ dòng doi dua ganh tất thảy đều mong_manh dễ thay lòng đổi dạ duy chỉ mỗi mẹ thôi thương con bằng tất_cả',
#  'còn trẻ mà hãy thực_hiện đi y thuong thuong chinh tuyết ht thanh trần hương trần mai phương giang thị hương phạm bò thảo trang vân',
#  'moi do thui hi',
#  'áo lớp_học_sinh của cô_giáo nhâm kim bôi hoà_bình áo xanh long_lanh nhất trường rùi',
#  'không biết nói sao cho đúng nếu đã không hiểu về mình thì tôi chọn cách im_lặng mặc_kệ người_đời',
#  'chung_kết rôi',
#  'quá nhọ cho vào đội bá lọ h sáng đó bà_con',
#  'đag ùi cần thơ vui quá sắp bão ùi',
#  'mình có một_số mẫu đồng_hồ michael kors hàng chính hãng nguyên hộp nhập được_giá cực tốt bạn nào thích alo comment mình báo_giá tốt nhé giá chênh_lệch thị_trường từ đến link ảnh các sản_phẩm đây nhé link_website zalo viber phone số_điện_thoại link_website địa_chỉ nguyễn huy tự free ship toàn_quốc nhé giao hàng thu tiền',
#  'đi ngủ ngày_mai tiếp_tục với cuộc_sống của mình hẹn gặp lại đạt trần minh trọng văn trần',
#  'lam nguoi hung am nhac',
#  'trong cuộc_sống hàng ngày có rất nhiều người có thói_quen không coi_trọng những đồng_tiền_lẻ tiền rách vứt tiền khắp nơi trong nhà họ không biết rằng chính những việc_làm này có_thể khiến gia_đình quanh_năm mạt_vận kinh_tế khó_khăn sa_sút rất ít người nhận ra rằng những thói_quen nhỏ nhất trong việc sử_dụng tiền cũng ảnh_hưởng không nhỏ đến tài_lộc gia_đình chính vì_vậy cần phải coi_trọng đồng_tiền khi chi_tiêu và phải tuyệt_đối tránh những việc_làm sau more words link_website',
#  'đón_dâu',
#  'năm nay về thằng em đã cao nhất nhà rồi',
#  'hết giờ chs rùi về thui',
#  'chào xuân khuyến_mãi giá chỉ còn giá_sản_phẩm giá gôc giá_sản_phẩm áo_khoác cách_điệu nỉ phối dù cực nữ_tính hàng bao đẹp ship toàn_quốc mới thanh_toán tiền khách muốn mua chỉ cần để lại sđt mọi thắc_mắc sẽ có nhân_viên goi tư_vấn kỹ từ a tới z nhé ® số_lượng có_hạn nhanh tay lên số_điện_thoại số_điện_thoại áo_khoác được làm từ chất_liệu nỉ phối dù from đẹp không đổ lông khi mặc lâu_dài cam_kết áo giống hình lưu_ý giá đã giảm và mã sản_phẩm có ghi trên hình chúng_tôi cam_kết bán đúng hình đúng giá niêm_yết hài_lòng về sản_phẩm sản_phẩm có bảo_hành về kĩ_thuật vĩnh_viễn được đổi trả hàng trong vòng ngày kể từ khi nhận hàng giao hàng cực nhanh thu tiền tận nơi trên toàn_quốc tphcm ngày khu_vực khác ngày làm_việc ai mặc cũng đều khen đẹp sl đặt_hàng ngày_càng nhiều nhanh tay mua ngay kẻo hết địa_chỉ quốc_lộ 1a khu_phố 1a phường tân thới hiệp q tp hcm',
#  'nhiều lúc đi xe ngoài đường rất muốn được thả hồn theo mây nhưng lại sợ _răng bay theo gió',
#  'em không mong ngày_mai sẽ bình_yên hay như_ý chỉ mong luôn đủ sức để bất_ngờ nào đến cũng bình_thản dang tay',
#  'sao ty cua a traj laj co ljen wa den ty cua t t nan wa taj sao laj nhu the',
#  'ủa nhớ lâu hơn mà ta',
#  'ayo hôm_nay mùng con lạy các cụ ạ',
#  'mưa_gió thèm thịt chó',
#  'cảm_ơn các anh các chị các em và các cháu đã chúc_mừng sinh_nhật tôi cảm_ơn những lời chúc thật là ý_nghĩa',
#  'parka unilqo lông_vũ to mà siêu nhẹ',
#  'nhớ cún cưng qua',
#  'qua da',
#  'memories    ',
#  'trời đang mưa và rất rét nhiệt_độ ngoài_trời đang là ° c nên toàn_bộ các đơn hàng khách hẹn giao sáng shop sẽ chuyển sang giao chiều mong các khách thông_cảm ship shop thuê ngoài ngày qua tuy mưa rét nhưng shop vẫn thu ship khách ở mức cũ giá_sản_phẩm giá_sản_phẩm đơn và bù thêm giá_sản_phẩm đơn bt bù giá_sản_phẩm đơn e tâm_niệm giàu nghèo có số mỗi đơn bớt lãi giá_sản_phẩm m cũng ko nghèo đi đc nếu có số giàu d vs ship nó lại khác đó là sự chia_sẻ nên chị_em đừng mặc_cả miễn_phí ship mà phải_tội còn khách dù mua nhiều hay ít e vẫn ship nhiệt_tình dù chỉ là chiếc chì trời lạnh chị_em hãy luôn mặc ấm giữ_gìn sức_khoẻ nhé thân_ái',
#  'bị thích chụp hềnh trước gương là sao có bịnh nặng lắm k',
#  'mình yêu nhau đi anh của ngày hôm_qua anh yêu người khác rồi người nào đó người ấy là ai chính em á đù',
#  'hehe lau lau do ty',
#  'lễ sớm',
#  'chương_trình khuyến_mãi chỉ còn duy_nhất ngày_mai các quý_khách_hàng của sơmi việt hãy nhanh chân đến ngay showroom chùa láng đống đa hà nội để nhận nhiều ưu_đãi khi mua hàng nhé hotline số_điện_thoại website www somiviet com',
#  'giá_sản_phẩm b mua cái áo mặc vài bữa chán bạn bỏ nhưng giá_sản_phẩm vào đúng vị_trí có_thể giúp bạn trở_nên lột_xác và biến_hình_như nàng tiên bạn có tin gói cốm beone pluss tương_đương 1kg rau cu va những bạn lười ăn hoa_quả để hiểu hàm_lượng vitamin và chất xơ dồi_dào như nào để cho làn da b mọng như em bé số_điện_thoại',
#  'ca_khúc tôi yêu cà mau thơ ngọc nhiên nhạc thanh sử xin gửi tặng tác_giả thơ và nhạc_sĩ trần ngọc để hôi vhnt tỉnh cà mau',
#  'long time no see',
#  'top nữa',
#  'đến người lạ còn ko có thì_phải làm_sao',
#  'ẳng ẳng tiếng ex vụt qua tiêu đời con chó nhà_hàng_xóm',
#  'lanh qua',
#  '_______',
#  'lên chức quá đã',
#  'hélô bấy bê',
#  'c hang nhan hang nhe',
#  'là thằng đàn_ông tốt nhất_là ko nên nôn vào nhiều dầy',
#  'mới_đây năm ui không có gì thay_đổi vẫn độc_thân miệt_mài vào công_việc kiếm tiền',
#  'biến mẹ hết di',
#  'daj ca truog mầm_non',
#  'thua cũng hết_mình rồi',
#  'bao_giờ về đến nam định',
#  '      ',
#  'đại_học nông_nghiệp cùng lũ khốn lu_tham_an',
#  'khi không còn thứ gì ràng_buộc cứ từng thứ một biến mất em cũng không còn tồn_tại nữa đâu',
#  'cổ thạch đẹp ngây_ngất lòng người',
#  'buồn quá',
#  'cục cưng lần đầu lên sóng nè vợ yêu ơi',
#  'link_website y',
#  'không_khí tại làng đỗ duy mạnh',
#  'giọt nước_mắt rơi tình_yêu đã vơi khóc làm_gì rồi ngày_mai chia_ly cuộc tình đó mãi_mãi chỉ là mơ giờ hối_tiếc cũng chỉ vậy thôi yêu_thương giờ cũng đã quá xa_vời chỉ còn lại một_mình anh với nỗi đau khóc để làm_gì nhớ_mong chẳng được chi chỉ khiến cho ta thêm buồn ngày_tháng đó đã mãi xa rồi chỉ còn lại mình anh mà thôi khi ta yêu nhau đã không biết chân trọng những hạnh_phúc mà ông trời đã ban cám_ơn em những tháng_ngày qua luôn bên cạnh và quan_tâm về anh luôn đi bên anh những khi buồn vui mà giờ_đây tình mình vỡ đôi thôi đi người ơi những phút_giây đã xa_vời giờ hối_tiếc thì cũng quá xa_xôi anh sẽ dừng lại về nơi rất xa và cầu_chúc người luôn hạnh_phúc yêu_thương giờ cũng đã quá xa_vời chỉ còn lại mình anh với nỗi đau khóc để làm_gì nhớ_mong chẳng được chi chỉ khiến cho ta đau_đầu ngày_tháng đó đã mãi xa rồi chỉ còn lại mình anh mà thôi khi ta yêu nhau đã không biết chân trọng những hạnh_phúc mà ông trời đã ban cám_ơn em những tháng_ngày qua luôn bên cạnh và quan_tâm về anh luôn đi bên anh những khi buồn vui mà giờ_đây tình mình vỡ đôi thôi đi người ơi những phút_giây đã xa_vời giờ hối_tiếc thì cũng quá xa_xôi anh sẽ dừng lại về nơi rất xa và cầu_chúc người luôn hạnh_phúc',
#  'lang tu sy tinh',
#  'chuc con gai yeu tron 1tuoi vui ve hay an chonglon khoe manh cam on tat ca moi nguoj den sn sau na',
#  'thua chặt chặt chặt cu k nói nhiều',
#  'vo lang ngu ngon hoj',
#  'cam hà nội của mẹ tại vì đc gửi từ hn xuống nên gọi_là cam hn vãi mẹ',
#  'hay   ',
#  'con xe mới tậu của nhím con',
#  'ung ho nha ba con',
#  'chan vi y wa m yeu tkat lonh ma ko dc dap lai danh chuc em hanh phuc bien nguoi em yeu',
#  'này thơ_dại bước chậm lại đi những đêm không ngủ lew lew yêu quá chúc em cát tường',
#  'đăng cho biết sắp già thêm tuổi rồi nhớ mấy bả trong hình quạ',
#  'chai nước_hoa hot nhất nhà chanel',
#  'gio e moi ranh moi dang anh cua ngay hom qua dc',
#  'w ara hàng của hai em cưng chưa kìa mọi người ơi',
#  'áo_dài ren kute đây ạ chất_liệu ren free size 53kg',
#  'khi cầm vô_lăng là ad thường_xuyên nhường cho xe_máy hoặc người đi bộ sang đường ad nhớ có lần chạy chiếc c class ở đường_phố nha trang dừng xe lại cho người hàn quốc đi qua họ cúi đầu cảm_ơn vui lắm autodaily',
#  'đừng buồn nhé mọi người tuy hơi tiếc ở hiệp phụ nhưng thua trên thế thắng tôi yêu u23 việt nam',
#  'chuẩn_bị về thêm mẫu kem mới kem bb hàng của nhật các chế nha',
#  'tuyệt_vời các cầu_thủ việt nam các chiến_binh quả_cảm tự_hào việt nam việt nam',
#  'trung quốc điều tàu sân_bay tới eo_biển đài loan giữa lúc căng_thẳng dailoan lieuninh tausanbay trungquoc vietnam24h',
#  'có bác nào thích con vật tài_lộc này không _',
#  '⏩ ⏩ nhân_dịp noel tri ân khách_hàng giảm_giá cực mạnh ⏩ ⏩ bông_tai titan cao_cấp nay chỉ còn giá_sản_phẩm bao ship toàn_quốc ⏩ ⏩ set bộ chỉ còn giá_sản_phẩm bao ship toàn_quốc ⏩ ⏩ chất_liệu titan cao_cấp bền màu không gỉ nhanh tay để lại số dt họ tên địa_chỉ để sở_hữu bộ trang_sức cực đẹp để đón giáng_sinh nhé nhận hàng thanh_toán gọi ngay để được tư_vấn về sản_phẩm số_điện_thoại',
#  'hanh phuc nhe j ju oi',
#  'hy vong ngày mới',
#  'gui chi sdt cua me vs e chi mat so gjia djnh mjnh rui',
#  'link_website',
#  'mọi người ơi có ai có máy hàn điện cũ bán không',
#  'mừng xuân vị biển tặng khay đựng món khô khi quý_khách mua hàng từ món khô ăn_liền trở lên và đơn hàng trên giá_sản_phẩm nhé số_lượng có_hạn nên các tình_yêu đặt mạnh_tay lên nhé ít ăn món khô cũng ko sao mua về tết mình đãi khách đảm_bảo lạ ngon mà giá_cả hợp_lý hotline đặt_hàng số_điện_thoại số_điện_thoại chọn món tại link_website',
#  'video schannel trên tay galaxy s6 quốc_tế giá chỉ triệu flagship với giá tầm trung sau galaxy s6 mỹ schannel lại có dịp trên tay một sản_phẩm dự là cũng hot không kém đó là galaxy s6 quốc_tế qua sử_dụng cũng sở_hữu mức giá cực_kỳ hợp_lý chỉ triệu nhưng lại không phải lo app rác hay chạy rom cook như bản mỹ đây được coi là sự lựa_chọn tuyệt_vời khi trung hòa giữa giá tiền hiệu_năng và độ ổn_định link_website giá tại galaxy s6 tại cellphones link_website',
#  'u23 làm_nên lịch_sử của lịch_sử',
#  'buồn quá lúc hết tiền là em lạ thấy buồn kinh_khủng',
# ...
#  'mình đang đọc sách đấy',
#  'sinh_nhật vui_vẻ hạnh_phúc và thành_công nha ku',
#  'link_website',
#  'màu và màu hok có nha tất_cả các màu còn lại thì_có đủ inbox nha nha',
#  'năm nay đang hot kiểu chân_mày này chị_em bạn_bè nào có nhu_cầu làm_đẹp ghé tmv của chị mình làm nhé bao đẹp giá cũng đẹp luôn nhé',
#  '_ quen_biết đầy thiên_hạ tri_kỷ được mấy người',
#  'nhìn cấy lịt oẹ cm',
#  'whoo all in one treatment tinh_chất vạn_năng đặc_trị mọi vấn_đề về da tinh_chất whoo all in one treatment được tạo thành từ đơn thuốc ngự y hoàng_cung có khả_năng cải_thiện nếp nhăn chỉ một sản_phẩm có_thể thay_thế cho nhiều sản_phẩm nước_hoa_hồng sữa dưỡng tinh_dầu đem lại dưỡng_chất dồi_dào và độ đàn_hồi cho da giúp bạn tiện hơn trong các khâu dưỡng da thành_phần_đông_y cô đặc trong sản_phẩm giúp cải_thiện làn da cho da săn chắc sáng mịn sản_phẩm thẩm_thấu nhanh sau khi dùng giúp da mềm mịn mà không bị nhờn giảm_thiểu sự xuất_hiện của nếp nhăn làm sáng da cải_thiện các vấn_đề về da như nám da đồi_mồi mụn bảng giá mini size 30ml giá_sản_phẩm full size 120ml 3giá_sản_phẩm',
#  'từ nay lại nuôi thêm em này nữa',
#  'tet nay tui dia we cam cau rui may ban',
#  'co aj di uog cafe hok',
#  'hôm_nay trăng rất lạ',
#  'lạnh sơ_sơ',
#  'cần lắm một cái kết đẹp',
#  'những điều xảy ra không như_ý thì mình nên thưởng_thức nó niềm đau cũng thưởng_thức sự thất_bại cũng_nên thưởng_thức nếu muốn có được sự thành_công phải trả_giá bằng sự thất_bại phải_biết khổ_sở đến mức mà nó nhiều hơn hạnh_phúc thì khi đó chúng_ta mới biết quý_trọng tưng phút_giây mà mình gặp ai và làm_gì không nên đánh_giá một người chỉ dựa vào những gì bạn thấy và quan_sát một_cách thiếu tinh_tế những lầm_lỗi của con_người là do một lý_do nào đó rất chính_đáng khi người_ta lãnh tiền để làm_gì thì không_thể_nào người_ta lại xem_thường chén cơm bát gạo của mình được nếu mình đã hiểu cuộc_đời ở một khía_cạnh khác thì khi mình mắc phải một sai_lầm nào đó thì người khác cũng sẽ đối_xử với mình một_cách chính_đáng và vị_tha như cách mà bản_thân đã làm với cuộc_đời họ',
#  'vltkm kcgh tangkiem truongca',
#  'to start out',
#  'xin chào tất_cả các bạn tin nóng rất lấy làm vinh_hạnh vì được làm_quen đến tất_cả bạn_bè fb gần_xa tin nóng ra_đời với mong_muốn đem đến cho các bạn những tin_tức_thời_sự nóng và mới nhất trong ngày nhằm giúp chúng_ta có cái nhìn đa_chiều về một vấn_đề như thông_tin kinh_tế pháp_luật văn hóa thể_thao và đời_sống xã_hội hãy cùng nhau bình_luận phân_tích đánh_giá với góc_độ đa_phương hóa đa_dạng hóa ý_kiến của tất_cả các bạn về những vấn_đề mà chúng_ta cùng quan_tâm chúng_ta hãy thể_hiện sự văn_minh chuẩn_mực trong bình_luận không_kích_động bạo_lực không_kích_động tôn_giáo không_kích_động sắc_tộc không chính_trị hóa các vấn_đề chân_thành cảm_ơn quí anh_chị và các bạn',
#  'niềm vui chợ_phiên bắc hà mà vui thật chớ',
#  'trung_thu cua e',
#  'cầm tay anh và quay lại với anh được không đừng yêu ai mà em để anh tre trở em dù đôi_khi giận nhau nhưng anh tin một điều người_thương em nhất_là anh anh vẫn còn yêu',
#  'mouse lightning g688 chất_lượng theo phong_cách đơn_giản mouse lightning chuyên game g688 được thiết_kế nút có đèn led đổi màu liên_tục có_thể điều_chỉnh tốc_độ của chuột theo ý_muốn nhờ có nút dpi nằm ngay chính giữa thân chuột rất tiện_lợi cho người dùng điều_chỉnh nhanh chậm theo độ phân_giải tuỳ_thích nút back forwod được thiết_kế cứng vững trên giá đỡ kim_loại chịu được lực tỳ lớn ko bị hiện_tượng móp phím vị_trí nút trên được thiết_kế gọn_gàng ko tạo sự vướng_víu trong khi sử_dụng chất_lượng siêu bền với nút click kailh đỏ đạt trên triệu lần click chip sét a5050 cho độ chính_xác cao dây dù to lõi đồng mềm_mại chống xoắn dài giá_sản_phẩm có chống nhiễu sp được bh năm kiểu_dáng thon gọn thời_trang với những tính_năng kỹ_thuật vượt_trội chắc_chắn sẽ làm hài_lòng quí_khách giá bán_lẻ giá_sản_phẩm bh tháng sl cho game net ace liên_hệ liên_hệ số_điện_thoại',
#  'một tuần ở lại thật',
#  'ae solo',
#  'em nhớ a lắm nhưng e chẳng dám nt gọi điện cho a chỉ biết lặng_lẽ dõi theo a thôi đêm ngủ vẫn nằm_mơ thấy a a ạ em không quên được a mất',
#  'ngay di nhau ve nha buon wa ban oi',
#  'ai chống lưng mà tại_sao lại vẫn ngang_nhiên như vậy nhỉ',
#  'ba the he',
#  'em làm_sao ta',
#  'gương_mặt thân_quen',
#  'giáng_sinh an_lành bình an và tốt_đẹp cho anh_chị_em ps cảm_tạ vì bao sóng_gió trôi qua bình_yên hạnh_phúc luôn ở lại',
#  '',
#  'hay quá việt nam ơi',
#  'bão_hoà cảm_xúc không cần ai cũng chẳng muốn ai',
#  'happy birthday chế chúc chế phương mau có bồ chế vi mau láy chồng hạnh_phúc va vui_vẻ nha',
#  'huỳnh thánh y không giấu nổi niềm hạnh_phúc khi được khoác lên mình tấm váy cưới hạnh_phúc bên ông_xã dương tử mynhanhoangu vietnam24h',
#  'quân tât lơp bộ thể_thao',
#  'ca gia dinh nhan ngay',
#  'nhanh chi nhi',
#  'sau 30t thì kết_thúc một ngày làm_việc người_ta chỉ muốn trở về nhà',
#  'đậu_phộng thằng nicolai nhaidepxop nhe',
#  'làm_gì vậy em',
#  'buổi chiều tốt_lành ạ online watch',
#  'có_tình iu nào muốn đẹp như chị ấy không liên_hệ tư_vấn số_điện_thoại nguyễn liên hải phòng',
#  'trời_ơi',
#  'xinh_đẹp ko bằng sống đẹp đâu e ak',
#  'mẫu nhí nhà em vân navi',
#  'e có biết luật việt_vị khônggg',
#  'quần_đùi áo rách phong_cách nhà_quê',
#  'nguyễn trâm oanh thao thảo_nguyên zô',
#  'theo yêu_cầu của nhiều khách_hàng đợt này em về loại trứng vịt vữa nước kèm rau_răm và muối_tiêu loại trứng to giá_sản_phẩm chục to trứng ngỗng loại trứng vừa giá_sản_phẩm chục chiều em ship khu_vực tdm đến chợ bến cát khách nào muốn thưởng_thức trứng vịt vữa nước ib hay cam',
#  'e đang muốn tìm e lip out lander cụ nào có ới e số_điện_thoại',
#  'thời_gian làm chúng_ta quên mất mình đã từng như vậy',
#  'link_website',
#  'tôi thấy các bạn có vẻ hơi ảo_tưởng về sức_mạnh của đội bóng rồi đấy vào được đến chung_kết là đã may_mắn lắm rồi đừng mơ_tưởng những thứ không thuộc về mình nữa một đội bóng tên_tuổi mờ_nhạt trên bản_đồ bóng_đá thế_giới vậy_mà chiều lại còn gặp một đội mạnh như việt nam nữa uzb à các bạn ảo_tưởng quá rồi đấy',
#  'ngày này năm trướctui vẫn thế bây_giờ tui cũng chẳng thấy khá hơn chỉ hơn là có những anh_em gần_gũi quan_tâm tui hơn biết lo_lắng cho tui thế la vui rui tốt thì tui tốt lai k thì',
#  'nếu bạn đúng bạn không cần phải nổi_giận nếu bạn sai bạn k có tư_cách để nổi_giận nổi_giận là bản_năng khống_chế được cảm_xúc là bản_lĩnh',
#  'the co nay hay nhung ko co loi dai',
#  'chuyện hồi chiều',
#  'ktp coi u23 đáng thương quá đi',
#  'ca ngay phai nhu zay met wa jo ngu thui ca nha ngu ngon n9o o',
#  'dép sandal vento khối_lượng gram giá bán vnđ kích_cỡ size liên_hệ giá_sản_phẩmail nguvantai007 @ gmail com giao hàng tận nơi hcm',
#  'nam trước',
#  'bắt_đầu',
#  'chẳng dễ_dàng gì để xem đượccoi bộ sống cũng có đức tí',
#  'ngày_xưa',
#  '2og trùm nha tui',
#  'hai anh_em và một quả khế',
#  'nhìn là biết cây mai đẹp rồi',
#  '',
#  'con gai oi me nho con wa',
#  'bao nhieu no luc cua toi the la bang thua het',
#  'hahhaha đã bị',
#  'happy birthday to me cám_ơn em gì mọi thứ',
#  'thuỷ_tiên',
#  'quá đông quá nguy_hiểm',
#  '',
#  'cơm muộn',
#  'e co chiếc long cam do nan ja ca họp ly ae nao co nhu cau sin de lai so dien',
#  'thay may em br toi nghep qua ha cac chi em oi o ben vn phu giup may chi mui cac be do voi thay toi nghep qua ha',
#  'đỗ rồi chị e mình lại đc gặp nhau rồi zêêê',
#  'không đồng_hành cùng mọi người đến kết_thúc nhưng vẫn cố_gắng tạo động_lực cho mọi người chúc tất_cả có những ngày trung_thu ý_nghĩa nơi xa nha các thầy làm_việc tốt nhé',
#  'nghe bảo dunu sắp có cơ_sở mới gần biển hơn là khách nhà dunu ai cũng hào_hứng lắm đảm_bảo với các khách yêu là phải đẹp hơn dunu nhé homestaydanang',
#  'chuyện hôm_kia bây_giờ mới khai àh hiiii',
#  'rét thế này mua quần tất lót lông về giữ ấm thôi khách ơiiii quần lông dày chất thì đẹp miễn bàn rồi b giá lẻ từ sale còn giá_sản_phẩm liên_hệ giá_sản_phẩm c dung style đường láng',
#  'giog me con k nek hj luk nao mk ms dk 1dua nhu tnay nhj',
#  '         ',
#  'nhân ngày lễ tình_yêu cháu nội tặng ông_bà món quà chúc ông_bà mãi khoẻ_mạnh cho cháu nhiêu quà',
#  'và nay giày nam không chỉ có giày nam www giaynamthoitrang net',
#  'nhậu đi các chiến_hữu ơi',
#  'vãi loằn',
#  '019xjfjr',
#  'no_nê _ nhìu khi thấy đi 1mình cũng hay p s giá_sản_phẩm từ hôm_nay sẽ tập đi mình',
#  'ỷ',
#  'an giang',
#  'được các ông a dạy cho luyện rượu để cbi đi thi_đấu kaka',
#  'không biết có ai muốn ăn rau_câu hong ta',
#  'nhân_dịp năm mới khuyến_mãi thay màn_hình điện_thoại cảm_ứng và sửa điện_thoại lấy liền giá chỉ từ giá_sản_phẩm lần tùy theo máy tư_vấn miễn_phí số_điện_thoại địa_chỉ lý chính thắng p7 q3 nhận và giao máy tận nơi luôn trọng ân mobi chuyên chuyên chuyên ép mặt kính cảm_ứng sửa_chữa và thay_thế linh_kiện điện_thoại chuyên thu_mua mua_bán trao_đổi điện_thoại thông_minh giá từ triệu trở lên truy_cập website www suadienthoailaylien • webnode • vn',
#  'tượng_trưng cuộc_sống của hiện_tại',
#  'doj luc mj hjeu nham ck mj n that su ck mj la ngtot',
#  'thanh_xuân ơi',
#  'đa co khach taxi đau tien',
#  'da chjnh thuc bi gai lua bum ko cuoi duoc nhung co nguong cuoi de che di noi bum no you thag khac mat roi no ko you mjnh nua paj chuc no hp thoi',
#  'yay we won long time no watch soccer such old exciting feeling i m so happy glad that vietnam won the semifinal',
#  'lại cpi xa quê thôi nhớ cái nơi này lm đấy',
#  'chưa bao_giờ đen như bây_giờ',
#  'đầm kim_tuyến giá giá_sản_phẩm',
#  'việt nam_vô_địch',
#  'hôm_nay cưới cháu mình',
#  'thanh_lý belt lv like new mẫu belt chữ lồng mặt gold quá kinh_điển của lv da dập vân lv cực đẹp và sắc nét tình_trạng like new dây thẳng_tắp lỗ còn rất đẹp phụ_kiện còn dustbag belt size bản 3cm chuyên thắt quần_âu giá thanh_lý cực tốt sold out anh_em mua hàng liên_hệ số_điện_thoại hoặc số_điện_thoại',
#  'kết ban facebook nha em',
#  'kiếp đỏ_đen',
#  'cũng ko khác_gì vuệt nm đâu nhá tưởng ko lạnh mà_lại lạnh ko tưởng',
#  'mừng đội_tuyển u23 việt nam chiến_thắng e đi chơi đây',
#  'sao không_thể_nào ngủ được vậy',
#  'chúng_ta sinh ra là để giành cho nhau ahêê',
#  'ban the này thi làm_gì còn thoi gian tán gai các bác',
#  'cả nhà mình có ai ngủ mà chưa thoa cao nịt bụng k chưa thì hãy thoa thoa và nịt lại rồi hãy đi ngủ nha để dc vòng eo thon gọn nak',
#  'tết tới rồi',
#  'phai dua za quyet dinh thoi uk thj ve',
#  'yen bai',
#  'đi nào',
#  'ngồj chầu_chực',
#  'tại_sao không phải là chính mình',
#  'kỷ_niệm năm chụp kỷ_yếu nè quỳnh kandy',
#  'cung dao hoa nhu ai thoi',
#  'kí rưỡi',
#  'sang nguyen chuan bi nha',
#  'hồi xưa đẹp lắm giờ đỡ nhiều rồi',
#  'người lạ ơi có cần mượn bờ vai không nè mod le huynh photo ngày_tháng năm',
#  'năm kìa nhi',
#  'chuẩn_bị tinh_thần đi kíp ngày chị nhé',
#  'tam biet son duong hen gap lai',
#  'phê chưa mấy chú',
#  'tonight nhớ hẹn chế đi tơi nhé huyền tâm',
#  'nếu bây_giờ mà mình thích naked heat quá mà không có tiền mua thì mình mua bảng này về mình đánh cho đỡ ghiền nha mấy chế giá siêu đẹp màu siêu bám tone màu hot trend nha chưa đến để sở_hữu bảng mắt xinh_xắn này nha kim ’ s house cosmetic tools đại_lý chính_thức của celin tools accessories tại thành_phố hồ chí minh add phan đình phùng p tân thành quận tân phú tp hồ chí minh mở_cửa 9h30 19h phone số_điện_thoại ms hiền hot line số_điện_thoại 10h 19h',
#  'chúc e hạnh_phúc',
#  'lâu quá rồi đó a',
#  'to bi khoa f nen lap lai mong ban be gan xa thong cam nhe xin cam on',
#  'thông_báo nghĩ tết bính thân để đảm_bảo cho nguồn lợi của khách_hàng được tốt nhất chất_lượng sản_phẩm và dịch_vụ cho khách_hàng được tốt nhất store đang bổ_sung một_số yếu_tố hy_vọng sau thời_gian nghĩ này 7store sẽ làm hài_lòng các bạn thời_gian nghĩ bắt_đầu_từ âm_lịch đến ngày âm_lịch bắt_đầu nhận đơn hàng hy_vọng sẽ được đồng_hành trên con đường kinh_doanh quần_áo thời_trang link_website',
#  'việc nhẹ lương cao',
#  'bánh_tráng trộn nguyên_nhân khiến cho nhiều người fải hái xùa trog bóg đêm',
#  'loa loa loa loa minh xa kho nen thanh ly het nen ae nao thich thi ib cho minh số_điện_thoại',
#  'tuổi ko ai theo_đuổi ai ở bmt tối rủ đi chơi đi',
#  'hay luon bao ve va cho che cho nguoi ma ban yeu thuog nhe va dac biet hon nua la dug lam ng ta ton thuong vi ban chuc ban lun hp ben nguoi ban yeu thuong',
#  'ngoi buon',
#  'thức đêm mới biết đêm dài',
#  'valungtung ca c e ta ohoh',
#  'sống ảo đếm từng ngày để được về nhà',
#  'nguyễn hợp bon bin nguyễn phương anh hồng huong ly nguyen nam hải hạt_tiêu nguyen nga hau nguyen gia huy',
#  'thạc thạc dũng',
#  'world water day tomorrow join us for our clean up action at hon mun island special rate for any volunteer',
#  'ae từ đến phước an mai thi tốt nha',
#  'facebook có bạn_bè ng theo_dõi mà không thèm like không tương_tác là trinh block đấy like cmt đi',
#  'mong rằng ba mẹ vẫn khỏe mạnh bản_thân chín_chắn trưởng_thành hơn',
#  'bộ mắt_kính little về hàng rồi các mom ơi giá niêm_yết giá_sản_phẩm giá_sản_phẩm về shop giảm ngay nha shop luôn đủ bộ sưu_tập mới nhất cho cả bé trai bé gái inbox để dc tư_vấn size cho các mẹ nhé các mom comment inbox cho shop để dc tư_vấn và có_giá yêu nhất nhé màu đẹp size có_thể hết rất nhanh các mẹ nhanh tay nhé để chọn cho con những bộ đồ chất_lượng nhất dễ_thương nhất miễn_phí vận_chuyển khi mua hàng qua shopee với đơn hàng trên giá_sản_phẩm số_điện_thoại link_website',
#  'quá hay việt nam',
#  'co của a vinh đôi',
#  'tôi đau tim quá anh_em à',
#  'năm mới chúc tất_cả ace thêm một tuổi mới mạnh khoe gai thi cang ngay cang xinh_đẹp va kon trai cang ngay cang dẹp trai con dj học thi học giỏi di làm thì kiếm được nhiều tiền va sim lay vk ca xom lay ck',
#  'mạnh ghê',
#  ...]

# %%
naive_predict = Naive.predict(Tfidf_vect.transform(input_data_))
svm_predict = SVM.predict(Tfidf_vect.transform(input_data_))

# %%
naive_predict_label = [SELL if x == 0 else NON_SELL for x in naive_predict]
with open('./data/naive.txt', 'w') as f:
    for item in naive_predict_label:
        f.write("%s\n" % item)

# %%
svm_predict_label = [SELL if x == 0 else NON_SELL for x in svm_predict]
with open('./data/svm.txt', 'w') as f:
    for item in svm_predict_label:
        f.write("%s\n" % item)

# %% [markdown]
# ## Đoạn sau này thử thôi, đừng bận tâm

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer

# from yellowbrick.text import TSNEVisualizer
# from yellowbrick.datasets import load_hobbies

# # # Load the data and create document vectors
# # corpus = load_hobbies()
# # tfidf = TfidfVectorizer()

# # X = tfidf.fit_transform(corpus.data)
# # y = corpus.target

# # Create the visualizer and draw the vectors
# tsne = TSNEVisualizer()
# tsne.fit(Train_X_Tfidf, Train_Y)
# tsne.show()

# %%
# import seaborn as sns
# import matplotlib.colors as mcolors
# import matplotlib.pyplot as plt
# cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

# fig, axes = plt.subplots(2,1,figsize=(16,14), dpi=160, sharex=True, sharey=True)

# for i, ax in enumerate(axes.flatten()):
#     doc_len1 = [len(str(d)) for d in data_sells]
#     doc_len2 = [len(str(d)) for d in data_nonsells]
#     doc_lens = doc_len1 + doc_len2
#     ax.hist(doc_lens, bins = 1000, color=cols[i])
#     ax.tick_params(axis='y', labelcolor=cols[i], color=cols[i])
#     sns.kdeplot(doc_lens, color="black", shade=False, ax=ax.twinx())
#     ax.set(xlim=(0, 1000), xlabel='Document Word Count')
#     ax.set_ylabel('Number of Documents', color=cols[i])
#     ax.set_title('Topic: '+str(i), fontdict=dict(size=16, color=cols[i]))

# fig.tight_layout()
# fig.subplots_adjust(top=0.90)
# plt.xticks(np.linspace(0,1000,9))
# fig.suptitle('Distribution of Document Word Counts by Dominant Topic', fontsize=22)
# plt.show()

# %%
# import collections
# import re
# import matplotlib.pyplot as plt

# # file = open('../data/sell.csv', 'r')
# # file = file.read()
# from matplotlib.pyplot import figure
# figure(num=None, figsize=(50, 40), dpi=80, facecolor='w', edgecolor='k')
# doc_len = collections.defaultdict(int)
# """ 
# the next paragraph does all the counting and is the main point of difference from the original article. More on this is explained later.
# """
# # \W is regex for characters that are not alphanumerics.
# # all non-alphanumerics are replaced with a blank space using re.sub
# def cal_len(data):
#     for line in data:
#         l = int(len(line.split())/10)*10
#         if l < 1000:
#             doc_len[l] += 1
#         else:
#             doc_len[1000] +=1
#     return doc_len

# d = cal_len(data_nonsells[0])

# # # printing most common words
# # to_print = 25
# # # the next line sorts the default dict on the values in decreasing  # order and prints the first "to_print".
# # mc = sorted(wordcount.items(), key=lambda k_v: k_v[1], reverse=True)[:to_print] # this is continued from the previous assignment
# # for word, count in mc:
# #     print(word, ":", count)

# mc = sorted(d.items(), key=lambda k_v: k_v[0], reverse=True)

# def loai(var):
#     return var[1] > 10

# mc = filter(loai,mc)
# # Draw the bar chart
# mc = dict(mc)
# names = list(mc.keys())
# values = list(mc.values())

# plt.barh(range(len(mc)),values,tick_label=names)
# plt.savefig('bar2.png')
# plt.show()
# mc
